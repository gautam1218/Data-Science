# %% [markdown]
# <a href="https://colab.research.google.com/github/gautam1218/Data-Science/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun_name(parameters):
  #body of the function
# Out:
#   File "/tmp/ipykernel_7946/3163548094.py", line 2
#     #body of the function
#                          ^
# SyntaxError: incomplete input

# %%
  def addTonum(a,b):
    return a+b
  print(addTonum(2,3))
# Out:
# 5

# %%
#lambda function
x = lambda a : 2*a
print(x(5))
# Out:
# 10

# %%
x=lambda a,b : a*b
print(x(4,5))
# Out:
# 20

# %%
x=lambda a : a*2
print(x(5))
# Out:
# 10

# %%
st = ""
print(len(st))

st = "gautam"
x=st.upper()
print(x)

st1 = "GAUTAM"
x1 = st1.lower()
print(x1)


st2 = "gautam kumar singh"
x2 = st2.capitalize()
print(x2)

st3 = "gautam kumar singh"
x3 = st3.title()
print(x3)

st4 = "Guatam"
x4 = st4.find("t")
print(x4)


st5 = "Guatam"
x5 = st5.count("a")
print(x5)
# Out:
# 0
# GAUTAM
# gautam
# Gautam kumar singh
# Gautam Kumar Singh
# 3
# 2

# %%
st = "            Guatam Kumar Singh     "
#strip
x = st.strip()
print(x)
# Out:
# Guatam Kumar Singh

# %%
first_name = "    Gautam    "
last_name = "   Singh    "
f_n = first_name.strip()
l_n = last_name.strip()
print(f_n +" "+ l_n)
# Out:
# Gautam Singh

# %%
a = " today "
b = "   weather   "
c = "is GooD    "

a = a.strip()
b = b.strip()
c = c.strip()
# print(a+" "+b+" "+c)
x=a+" "+b+" "+c
print(x.capitalize())
y=x.replace("GooD","bad")
print(y)
# Out:
# Today weather is good
# today weather is bad

# %%
#startswith()
#endswith()
st = "Guatam kumar singh"
x=st.startswith("G")
y=st.endswith("fgh")
print(x)
print(y)
# Out:
# True
# False

# %%
s="hello world"

print(s[-5:])
# Out:
# world

# %%
st = {2,4,6,6,1,2,4,6,9}
print(st)
#explore all the function of set itself'

st2 = {3,5,6,2,3,4,9,0,67,4}
print(st2)
# Out:
# {1, 2, 4, 6, 9}
# {0, 2, 3, 4, 5, 6, 67, 9}

# %%
dct = {
    "name" : ["Gautam","kunnu","prakhar"],
    "age" : 20,
    "city" : "Delhi"
}
print(dct)
print(dct['name'])
print(dct['name'][0])

dct['id']=54712
print(dct)

del dct['name']
print(dct)

dct.pop('age')
print(dct)

dct.clear()
print(dct)
# Out:
# {'name': ['Gautam', 'kunnu', 'prakhar'], 'age': 20, 'city': 'Delhi'}
# ['Gautam', 'kunnu', 'prakhar']
# Gautam
# {'name': ['Gautam', 'kunnu', 'prakhar'], 'age': 20, 'city': 'Delhi', 'id': 54712}
# {'age': 20, 'city': 'Delhi', 'id': 54712}
# {'city': 'Delhi', 'id': 54712}
# {}
