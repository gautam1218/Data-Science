# %% [markdown]
# <a href="https://colab.research.google.com/github/gautam1218/Data-Science/blob/main/OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class mirai_class:
  strength = 100
  teacher = ['A','B','C']
  div = ['alpha','beta']
  sub = ['DSA','DEV','DS']

  def __init__(self):
    print("hello dost")



obj = mirai_class()
print(obj.teacher)
# Out:
# hello dost
# ['A', 'B', 'C']

# %%
class student:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def display(self):
    print('Name :',self.name)
    print('Age :',self.age)

a = student('Gautam',19)
a.display()
# Out:
# Name : Gautam
# Age : 19

# %%
def sum(a,b):
  return a+b



def sum(a,b,c):
  return a+b+c

# %%
print(sum(3,5,c=0))
print(sum(3,5,2))
# Out:
# 8
# 10

# %%
class complex:
  def __init__(self,x,y):
    self.x=x
    self.y=y

  def __add__(self,other):
    # return complex(self.x+other.x,self.y+other.y)
    a = self.x+other.x
    b = self.y+other.y
    return complex(a,b)

  def display(self):
    print(self.x,'+i',self.y)


a = complex(2,3)
b = complex(4,5)


c = a+b
c.display()
# Out:
# 6 +i 8
